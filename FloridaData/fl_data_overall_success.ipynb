# %% [markdown]
# <a href="https://colab.research.google.com/github/gamountainmama/data_dames/blob/main/fl_data_overall_success.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the combined_data2122.csv
import pandas as pd 
df = pd.read_csv("https://gamountainmama.github.io/data_dames/FloridaData/combined_fl_data.csv")
df.head()
# Out:
#    Unnamed: 0  Grade  English Grade  Math Grade  Science Grade  \
# 0           2     12          92.47       90.86          92.95
# 1           8      9          96.56       90.75          87.52
# 2           9     11          92.98       96.70          93.15
# 3          10     11          92.98       96.70          93.15
# 4          11     10          85.08       81.70          86.12
#
#    Humanities Grade  Computer Science Grade  Computer Science A
# 0             93.96                   97.00                   1
# 1             94.93                   91.78                   1
# 2             95.58                   94.90                   1
# 3             96.00                   94.90                   1
# 4             89.27                   81.97                   0

# %%
# Drop the non-beneficial ID column 'Unnamed: 0'
df = df.drop(columns='Unnamed: 0', axis=1)

df.head()
# Out:
#    Grade  English Grade  Math Grade  Science Grade  Humanities Grade  \
# 0     12          92.47       90.86          92.95             93.96
# 1      9          96.56       90.75          87.52             94.93
# 2     11          92.98       96.70          93.15             95.58
# 3     11          92.98       96.70          93.15             96.00
# 4     10          85.08       81.70          86.12             89.27
#
#    Computer Science Grade  Computer Science A
# 0                   97.00                   1
# 1                   91.78                   1
# 2                   94.90                   1
# 3                   94.90                   1
# 4                   81.97                   0

# %%
# Determine the datatype of each column
df.dtypes
# Out:
# Grade                       int64
# English Grade             float64
# Math Grade                float64
# Science Grade             float64
# Humanities Grade          float64
# Computer Science Grade    float64
# Computer Science A          int64
# dtype: object

# %%
# Split our preprocessed data into our features and target arrays
X = df.drop('Computer Science A', axis=1).values
y = df['Computer Science A'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input = X_train_scaled.shape[1]
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation="relu", input_dim=input))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                70
#
#  dense_1 (Dense)             (None, 1)                 11
#
# ...
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 1s 4ms/step - loss: 0.3007 - accuracy: 0.4808
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2878 - accuracy: 0.5288
# Epoch 3/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2756 - accuracy: 0.5769
# Epoch 4/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.6058
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2515 - accuracy: 0.6490
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2404 - accuracy: 0.7115
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2299 - accuracy: 0.7404
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2206 - accuracy: 0.7692
# Epoch 9/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.7740
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=1)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0677 - accuracy: 0.9000
# Loss: 0.06768564134836197, Accuracy: 0.8999999761581421
