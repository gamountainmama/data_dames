# %% [markdown]
# <a href="https://colab.research.google.com/github/gamountainmama/data_dames/blob/main/kaggle_data_avg_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the exams.csv.
import pandas as pd 
df = pd.read_csv("https://gamountainmama.github.io/data_dames/KaggleData/exams.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86

# %%
# Add column for average score
df['total score'] = df['math score'] + df['reading score'] + df['writing score']
df['success'] = df['total score'].apply(lambda x: 0 if x < 210 else 1)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86
#
#    total score  success
# 0          207        0
# 1          276        1
# 2          210        1
# 3          203        0
# 4          254        1

# %%
df = df.drop(['math score', 'reading score', 'writing score','total score'], axis=1)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  success
# 0               completed        0
# 1                    none        1
# 2                    none        1
# 3                    none        0
# 4                    none        1

# %%
# Determine the number of unique values in each column.
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# success                         int64
# dtype: object

# %%
# Convert categorical data to numeric with `pd.get_dummies`
num_data = pd.get_dummies(df)
num_data.head()
# Out:
#    success  gender_female  gender_male  race/ethnicity_group A  \
# 0        0              1            0                       0
# 1        1              0            1                       0
# 2        1              1            0                       0
# 3        0              0            1                       0
# 4        1              1            0                       0
#
#    race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                       0                       0                       1
# 1                       0                       0                       1
# 2                       0                       0                       1
# 3                       1                       0                       0
# 4                       0                       0                       1
#
#    race/ethnicity_group E  parental level of education_associate's degree  \
# 0                       0                                               0
# 1                       0                                               1
# 2                       0                                               0
# 3                       0                                               0
# 4                       0                                               1
#
#    parental level of education_bachelor's degree  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    parental level of education_high school  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    parental level of education_master's degree  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    parental level of education_some college  \
# 0                                         1
# 1                                         0
# 2                                         1
# 3                                         1
# 4                                         0
#
#    parental level of education_some high school  lunch_free/reduced  \
# 0                                             0                   0
# 1                                             0                   0
# 2                                             0                   1
# 3                                             0                   1
# 4                                             0                   0
#
#    lunch_standard  test preparation course_completed  \
# 0               1                                  1
# 1               1                                  0
# 2               0                                  0
# 3               0                                  0
# 4               1                                  0
#
#    test preparation course_none
# 0                             0
# 1                             1
# 2                             1
# 3                             1
# 4                             1

# %%
# Split our preprocessed data into our features and target arrays
X = num_data.drop('success', axis=1).values
y = num_data['success'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=13)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input = X_train_scaled.shape[1]
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation="relu", input_dim=input))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                180
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 191
# Trainable params: 191
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 3s 14ms/step - loss: 0.8354 - accuracy: 0.5227
# Epoch 2/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.7934 - accuracy: 0.5240
# Epoch 3/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7623 - accuracy: 0.5280
# Epoch 4/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.7368 - accuracy: 0.5360
# Epoch 5/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7173 - accuracy: 0.5427
# Epoch 6/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.7018 - accuracy: 0.5467
# Epoch 7/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6893 - accuracy: 0.5600
# Epoch 8/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6782 - accuracy: 0.5827
# Epoch 9/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6684 - accuracy: 0.6080
# Epoch 10/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6601 - accuracy: 0.6173
# Epoch 11/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6526 - accuracy: 0.6240
# Epoch 12/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6460 - accuracy: 0.6267
# Epoch 13/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.6397 - accuracy: 0.6427
# Epoch 14/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6346 - accuracy: 0.6453
# Epoch 15/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6296 - accuracy: 0.6413
# Epoch 16/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6253 - accuracy: 0.6533
# Epoch 17/50
# 24/24 [==============================] - 0s 10ms/step - loss: 0.6214 - accuracy: 0.6533
# Epoch 18/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.6181 - accuracy: 0.6573
# Epoch 19/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6154 - accuracy: 0.6560
# Epoch 20/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6128 - accuracy: 0.6587
# Epoch 21/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6106 - accuracy: 0.6613
# Epoch 22/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6087 - accuracy: 0.6587
# Epoch 23/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6070 - accuracy: 0.6560
# Epoch 24/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6060 - accuracy: 0.6613
# Epoch 25/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6049 - accuracy: 0.6627
# Epoch 26/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6037 - accuracy: 0.6640
# Epoch 27/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6026 - accuracy: 0.6627
# Epoch 28/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6022 - accuracy: 0.6613
# Epoch 29/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6010 - accuracy: 0.6667
# Epoch 30/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6005 - accuracy: 0.6720
# Epoch 31/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5996 - accuracy: 0.6720
# Epoch 32/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5993 - accuracy: 0.6720
# Epoch 33/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5985 - accuracy: 0.6720
# Epoch 34/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5986 - accuracy: 0.6747
# Epoch 35/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5978 - accuracy: 0.6707
# Epoch 36/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5973 - accuracy: 0.6733
# Epoch 37/50
# 24/24 [==============================] - 0s 11ms/step - loss: 0.5969 - accuracy: 0.6733
# Epoch 38/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5964 - accuracy: 0.6733
# Epoch 39/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5960 - accuracy: 0.6680
# Epoch 40/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5957 - accuracy: 0.6707
# Epoch 41/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.5953 - accuracy: 0.6747
# Epoch 42/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5950 - accuracy: 0.6720
# Epoch 43/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5951 - accuracy: 0.6747
# Epoch 44/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.5943 - accuracy: 0.6720
# Epoch 45/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5940 - accuracy: 0.6733
# Epoch 46/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5940 - accuracy: 0.6720
# Epoch 47/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.5938 - accuracy: 0.6707
# Epoch 48/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5933 - accuracy: 0.6760
# Epoch 49/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5933 - accuracy: 0.6733
# Epoch 50/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5927 - accuracy: 0.6760

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=1)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 [==============================] - 1s 6ms/step - loss: 0.6665 - accuracy: 0.6400
# Loss: 0.666545569896698, Accuracy: 0.6399999856948853
