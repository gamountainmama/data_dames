# %% [markdown]
# <a href="https://colab.research.google.com/github/gamountainmama/data_dames/blob/main/KaggleData/kaggle_data_reading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the exams.csv.
import pandas as pd 
df = pd.read_csv("https://gamountainmama.github.io/data_dames/KaggleData/exams.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86

# %%
# drop math and writing columns
df.drop(columns=['math score'], inplace=True, axis=1)
df.drop(columns=['writing score'], inplace=True, axis=1)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  reading score
# 0               completed             70
# 1                    none             93
# 2                    none             76
# 3                    none             70
# 4                    none             85

# %%
# create column for passing reading
df['Reading Success'] = 0
df.loc[df['reading score'] >= 70, 'Reading Success'] = 1
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  reading score  Reading Success
# 0               completed             70                1
# 1                    none             93                1
# 2                    none             76                1
# 3                    none             70                1
# 4                    none             85                1

# %%
# drop the reading score column
df.drop(columns=['reading score'], inplace=True, axis=1)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  Reading Success
# 0               completed                1
# 1                    none                1
# 2                    none                1
# 3                    none                1
# 4                    none                1

# %%
# Determine the number of unique values in each column.
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# Reading Success                 int64
# dtype: object

# %%
# Convert categorical data to numeric with `pd.get_dummies`
num_data = pd.get_dummies(df)
num_data.head()
# Out:
#    Reading Success  gender_female  gender_male  race/ethnicity_group A  \
# 0                1              1            0                       0
# 1                1              0            1                       0
# 2                1              1            0                       0
# 3                1              0            1                       0
# 4                1              1            0                       0
#
#    race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                       0                       0                       1
# 1                       0                       0                       1
# 2                       0                       0                       1
# 3                       1                       0                       0
# 4                       0                       0                       1
#
#    race/ethnicity_group E  parental level of education_associate's degree  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = num_data.drop('Reading Success', axis=1).values
y = num_data['Reading Success'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=13)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input = X_train_scaled.shape[1]
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation="relu", input_dim=input))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                180
#
#  dense_1 (Dense)             (None, 1)                 11
#
# ...
# Total params: 191
# Trainable params: 191
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 3s 10ms/step - loss: 0.7448 - accuracy: 0.4880
# Epoch 2/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7141 - accuracy: 0.5160
# Epoch 3/50
# 24/24 [==============================] - 0s 13ms/step - loss: 0.6925 - accuracy: 0.5560
# Epoch 4/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6761 - accuracy: 0.5747
# Epoch 5/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6637 - accuracy: 0.5947
# Epoch 6/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6538 - accuracy: 0.6027
# Epoch 7/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.6462 - accuracy: 0.6133
# Epoch 8/50
# 24/24 [==============================] - 0s 9ms/step - loss: 0.6396 - accuracy: 0.6200
# Epoch 9/50
# 24/24 [==============================] - 0s 14ms/step - loss: 0.6336 - accuracy: 0.6253
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=1)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 [==============================] - 1s 3ms/step - loss: 0.6799 - accuracy: 0.6160
# Loss: 0.6799041032791138, Accuracy: 0.6159999966621399
